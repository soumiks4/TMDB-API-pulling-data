# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=d205a6c5d10292dae10f043488845b1a&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     100.683
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     100.700
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      60.113
# 3  The true story of how businessman Oskar Schind...   1993-12-15      51.331
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      29.773
#
#    vote_average  vote_count
# 0           8.7       16819
# 1           8.7       22545
# 2           8.6       10192
# 3           8.6       13384
# 4           8.6        3928

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,524):
    response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=d205a6c5d10292dae10f043488845b1a&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\theso\AppData\Local\Temp\ipykernel_17520\879474859.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\theso\AppData\Local\Temp\ipykernel_17520\879474859.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\theso\AppData\Local\Temp\ipykernel_17520\879474859.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\theso\AppData\Local\Temp\ipykernel_17520\879474859.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df.shape
# Out:
# (11320, 7)

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     100.683
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     100.700
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      60.113
# 3  The true story of how businessman Oskar Schind...   1993-12-15      51.331
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      29.773
#
#    vote_average  vote_count
# 0           8.7       16819
# 1           8.7       22545
# 2           8.6       10192
# 3           8.6       13384
# 4           8.6        3928

# %%
df.to_csv('movies2022.csv')

# %%
word = "all good in the hood"
response = requests.get(f"http://api.urbandictionary.com/v0/define?term={word}")
response.json()
# Out:
# {'list': [{'definition': 'Everythings [cool]. Nuthins [wrong].',
#    'permalink': 'http://all-good-in-the-hood.urbanup.com/123334',
#    'thumbs_up': 242,
#    'sound_urls': [],
#    'author': 'Looeez',
#    'word': 'all good in the hood',
#    'defid': 123334,
#    'current_vote': '',
#    'written_on': '2003-05-10T16:07:07.000Z',
#    'example': 'Me and that bitchass shaniqua were fightin, then i bout her sum [cheapass] [chocolates] and now [its all good] in the hood',
#    'thumbs_down': 70},
#   {'definition': 'means everything is perfect and going [well in] [your life] or [current] situation.',
#    'permalink': 'http://all-good-in-the-hood.urbanup.com/7175588',
#    'thumbs_up': 23,
#    'sound_urls': [],
#    'author': 'slang lover',
#    'word': 'all good in the hood',
#    'defid': 7175588,
#    'current_vote': '',
#    'written_on': '2013-09-15T08:24:02.611Z',
# ...
